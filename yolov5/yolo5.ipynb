# %%
# !pip install -r requirements.txt

# %%
# !python detect.py --weights ./md/hardhat-v06-28/weights/last.pt --img 416 --conf 0.50 --iou 0.30 --source ./data/images/batch3
# Out:
# detect: weights=['./md/hardhat-v06-28/weights/last.pt'], source=./data/images/batch3, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.3, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-10-20 torch 1.10.0+cu102 CPU
#
# Fusing layers...
# /home/gias/anaconda3/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 224 layers, 7056607 parameters, 0 gradients
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('runs/detect/exp20/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir md
# Out:
#       <iframe id="tensorboard-frame-a3ca2d7d0cf90602" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a3ca2d7d0cf90602");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
